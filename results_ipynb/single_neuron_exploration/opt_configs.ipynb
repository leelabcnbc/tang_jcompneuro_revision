# %%
from tang_jcompneuro.cnn_exploration import opt_configs_to_explore

# %%
a = opt_configs_to_explore()
assert len(a) == 8*4 + 3

# %%
a
# Out:
# OrderedDict([('1e-3L2_1e-3L2_sgd_mse',
#               {'conv': [{'l1': 0.0,
#                  'l1_bias': 0.0,
#                  'l2': 0.001,
#                  'l2_bias': 0.0}],
#                'fc': {'l1': 0.0, 'l1_bias': 0.0, 'l2': 0.001, 'l2_bias': 0.0},
#                'loss': 'mse',
#                'optimizer': {'lr': 0.1,
#                 'momentum': 0.9,
#                 'optimizer_type': 'sgd'}}),
#              ('1e-3L2_1e-3L2_adam005_mse',
#               {'conv': [{'l1': 0.0,
#                  'l1_bias': 0.0,
#                  'l2': 0.001,
#                  'l2_bias': 0.0}],
#                'fc': {'l1': 0.0, 'l1_bias': 0.0, 'l2': 0.001, 'l2_bias': 0.0},
#                'loss': 'mse',
#                'optimizer': {'lr': 0.005, 'optimizer_type': 'adam'}}),
#              ('1e-3L2_1e-3L2_adam002_mse',
#               {'conv': [{'l1': 0.0,
#                  'l1_bias': 0.0,
#                  'l2': 0.001,
#                  'l2_bias': 0.0}],
# ...
