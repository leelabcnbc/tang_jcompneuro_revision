# %%
import numpy as np

# %%
from tang_jcompneuro.io import load_split_dataset

# %%
from tang_jcompneuro.model_fitting_cnn import get_trainer

# %%
datasets = load_split_dataset('MkA_Shape', 'all', True, 553)

# %%
# this makes sure I have some numbers I can use as reference.
# this will help me make sure I don't make mistake when updating my cnn class.
trainer = get_trainer('2l_k5d2_k3d1p1.7', cudnn_enabled=False, show_every=500,
                      show_arch_config=True)
# Out:
# 2l_k5d2_k3d1p1.7 scale hack None
# {
#   "conv": [
#     {
#       "kernel_size": 5,
#       "out_channel": 7,
#       "stride": 1,
#       "bn": false,
#       "padding": 0,
#       "pool": null,
#       "dilation": 2
#     },
#     {
#       "kernel_size": 3,
#       "out_channel": 7,
#       "stride": 1,
#       "bn": false,
#       "padding": 1,
#       "pool": {
#         "kernel_size": 6,
#         "stride": 2,
#         "padding": 0,
#         "pool_type": "max"
#       },
#       "dilation": 1
#     }
#   ],
#   "fc": {
#     "factored": false,
#     "dropout": null,
#     "mlp": null
#   },
#   "act_fn": "relu",
#   "linear_output": true
# }

# %%
results = trainer(datasets)
# Out:
# [(6080, 1, 20, 20), (6080, 1), (1900, 1, 20, 20), (1900, 1), (1520, 1, 20, 20), (1520, 1)]
# CNN(
#   (conv): Sequential(
#     (conv0): Conv2d(1, 7, kernel_size=(5, 5), stride=(1, 1), dilation=(2, 2))
#     (act0): ReLU()
#     (conv1): Conv2d(7, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (act1): ReLU()
#     (pool1): MaxPool2d(kernel_size=(6, 6), stride=(2, 2), dilation=(1, 1), ceil_mode=False)
#   )
#   (fc): Sequential(
#     (fc): Linear(in_features=112, out_features=1, bias=True)
#   )
# )
# # of params 743
# ========starting phase 1/1==========
# ========starting epoch 500==========
# val metric
#  {'neg_corr': -0.53721511, 'corr': 0.53721511, 'mse': 0.0054308446}
# test metric
#  {'neg_corr': -0.48481557, 'corr': 0.48481557, 'mse': 0.0060411342}
# ========done epoch 500==========
# ========starting epoch 1000==========
# val metric
#  {'neg_corr': -0.62223202, 'corr': 0.62223202, 'mse': 0.0046709562}
# test metric
#  {'neg_corr': -0.57275337, 'corr': 0.57275337, 'mse': 0.0051920786}
# ========done epoch 1000==========
# ========starting epoch 1500==========
# val metric
#  {'neg_corr': -0.62265092, 'corr': 0.62265092, 'mse': 0.0047754417}
# test metric
#  {'neg_corr': -0.61092603, 'corr': 0.61092603, 'mse': 0.0051147761}
# ========done epoch 1500==========
# early stopping after epoch 1800
# ========end phase 1/1==========
# 1e-3L2_1e-3L2_sgd_mse 0.640144 39.968283891677856 sec
# CNN(
#   (conv): Sequential(
#     (conv0): Conv2d(1, 7, kernel_size=(5, 5), stride=(1, 1), dilation=(2, 2))
#     (act0): ReLU()
#     (conv1): Conv2d(7, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (act1): ReLU()
#     (pool1): MaxPool2d(kernel_size=(6, 6), stride=(2, 2), dilation=(1, 1), ceil_mode=False)
#   )
#   (fc): Sequential(
#     (fc): Linear(in_features=112, out_features=1, bias=True)
#   )
# )
# # of params 743
# ========starting phase 1/1==========
# ========starting epoch 500==========
# val metric
#  {'neg_corr': -0.55799121, 'corr': 0.55799121, 'mse': 0.0052662981}
# test metric
#  {'neg_corr': -0.53506327, 'corr': 0.53506327, 'mse': 0.0056487974}
# ========done epoch 500==========
# ========starting epoch 1000==========
# val metric
#  {'neg_corr': -0.61216581, 'corr': 0.61216581, 'mse': 0.004743665}
# test metric
#  {'neg_corr': -0.60784912, 'corr': 0.60784912, 'mse': 0.0048849611}
# ========done epoch 1000==========
# ========starting epoch 1500==========
# val metric
#  {'neg_corr': -0.64840388, 'corr': 0.64840388, 'mse': 0.0043918993}
# test metric
#  {'neg_corr': -0.65306097, 'corr': 0.65306097, 'mse': 0.0044229007}
# ========done epoch 1500==========
# ========starting epoch 2000==========
# val metric
#  {'neg_corr': -0.6263383, 'corr': 0.6263383, 'mse': 0.0046166014}
# test metric
#  {'neg_corr': -0.65781665, 'corr': 0.65781665, 'mse': 0.0043886248}
# ========done epoch 2000==========
# ========starting epoch 2500==========
# val metric
#  {'neg_corr': -0.61805522, 'corr': 0.61805522, 'mse': 0.0048649181}
# test metric
#  {'neg_corr': -0.65310413, 'corr': 0.65310413, 'mse': 0.0046755034}
# ========done epoch 2500==========
# early stopping after epoch 2500
# ========end phase 1/1==========
# 1e-3L2_1e-3L2_adam002_mse 0.648404 55.55868911743164 sec
# CNN(
#   (conv): Sequential(
#     (conv0): Conv2d(1, 7, kernel_size=(5, 5), stride=(1, 1), dilation=(2, 2))
#     (act0): ReLU()
#     (conv1): Conv2d(7, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (act1): ReLU()
#     (pool1): MaxPool2d(kernel_size=(6, 6), stride=(2, 2), dilation=(1, 1), ceil_mode=False)
#   )
#   (fc): Sequential(
#     (fc): Linear(in_features=112, out_features=1, bias=True)
#   )
# )
# # of params 743
# ========starting phase 1/1==========
# ========starting epoch 500==========
# val metric
#  {'neg_corr': -0.56048816, 'corr': 0.56048816, 'mse': 0.0052388948}
# test metric
#  {'neg_corr': -0.51395506, 'corr': 0.51395506, 'mse': 0.0057948478}
# ========done epoch 500==========
# ========starting epoch 1000==========
# val metric
#  {'neg_corr': -0.63734931, 'corr': 0.63734931, 'mse': 0.0045979284}
# test metric
#  {'neg_corr': -0.56501818, 'corr': 0.56501818, 'mse': 0.0052461829}
# ========done epoch 1000==========
# ========starting epoch 1500==========
# val metric
#  {'neg_corr': -0.64923203, 'corr': 0.64923203, 'mse': 0.0044329399}
# test metric
#  {'neg_corr': -0.60738868, 'corr': 0.60738868, 'mse': 0.0049798414}
# ========done epoch 1500==========
# ========starting epoch 2000==========
# val metric
#  {'neg_corr': -0.64687496, 'corr': 0.64687496, 'mse': 0.0044005932}
# test metric
#  {'neg_corr': -0.62141043, 'corr': 0.62141043, 'mse': 0.0047952491}
# ========done epoch 2000==========
# ========starting epoch 2500==========
# val metric
#  {'neg_corr': -0.63350123, 'corr': 0.63350123, 'mse': 0.0046480102}
# test metric
#  {'neg_corr': -0.62927896, 'corr': 0.62927896, 'mse': 0.0048296736}
# ========done epoch 2500==========
# early stopping after epoch 2500
# ========end phase 1/1==========
# 1e-4L2_1e-3L2_sgd_mse 0.649232 55.435880184173584 sec
# CNN(
#   (conv): Sequential(
#     (conv0): Conv2d(1, 7, kernel_size=(5, 5), stride=(1, 1), dilation=(2, 2))
#     (act0): ReLU()
#     (conv1): Conv2d(7, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (act1): ReLU()
#     (pool1): MaxPool2d(kernel_size=(6, 6), stride=(2, 2), dilation=(1, 1), ceil_mode=False)
#   )
#   (fc): Sequential(
#     (fc): Linear(in_features=112, out_features=1, bias=True)
#   )
# )
# # of params 743
# ========starting phase 1/1==========
# ========starting epoch 500==========
# val metric
#  {'neg_corr': -0.62260592, 'corr': 0.62260592, 'mse': 0.0047087856}
# test metric
#  {'neg_corr': -0.60498089, 'corr': 0.60498089, 'mse': 0.0051865131}
# ========done epoch 500==========
# ========starting epoch 1000==========
# val metric
#  {'neg_corr': -0.64830869, 'corr': 0.64830869, 'mse': 0.0044022603}
# test metric
#  {'neg_corr': -0.64997071, 'corr': 0.64997071, 'mse': 0.0045625502}
# ========done epoch 1000==========
# ========starting epoch 1500==========
# val metric
#  {'neg_corr': -0.65549302, 'corr': 0.65549302, 'mse': 0.0044024833}
# test metric
#  {'neg_corr': -0.67545283, 'corr': 0.67545283, 'mse': 0.0044792197}
# ========done epoch 1500==========
# ========starting epoch 2000==========
# val metric
#  {'neg_corr': -0.66404599, 'corr': 0.66404599, 'mse': 0.0042519593}
# test metric
#  {'neg_corr': -0.69119626, 'corr': 0.69119626, 'mse': 0.0041649207}
# ========done epoch 2000==========
# ========starting epoch 2500==========
# val metric
#  {'neg_corr': -0.66008759, 'corr': 0.66008759, 'mse': 0.0045905528}
# test metric
#  {'neg_corr': -0.69297105, 'corr': 0.69297105, 'mse': 0.0046424633}
# ========done epoch 2500==========
# early stopping after epoch 2800
# ========end phase 1/1==========
# 1e-4L2_1e-3L2_adam002_mse 0.665129 47.062925577163696 sec
# best config 1e-4L2_1e-3L2_adam002_mse with val 0.665129 and test 0.680480

# %%
for x, y in results.items():
    print(x, y)
    if isinstance(y, np.ndarray):
        print(y.shape, y.dtype)
# Out:
# y_test_hat [[ 0.22793065]
#  [ 0.208177  ]
#  [ 0.20896898]
#  ...,
#  [ 0.17101985]
#  [ 0.24180043]
#  [ 0.1760218 ]]
# (1900, 1) float32
# corr 0.68048
# attrs {'best_val': 0.66512859, 'best_config': '1e-4L2_1e-3L2_adam002_mse', 'inf_counter': 0}
