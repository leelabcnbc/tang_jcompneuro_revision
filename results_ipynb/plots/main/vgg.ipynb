# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from tang_jcompneuro.model_fitting_postprocess import load_data_generic
from tang_jcompneuro.model_fitting_cnnpre import blob_corresponding_info, subtype_to_train

# %%
def modelname_alternative(_1, x, _2, _3):
    net_name, _, blob = x.split('+')
    assert _ == 'legacy'
    return net_name + '$' +',{:02d},'.format(list(blob_corresponding_info[net_name]).index(blob)) + blob

# %%
def check_all(squared, score_col_name):
    models_to_examine = [
        ('cnnpre', x) for x in subtype_to_train  # both bn or nonbn
    ]
    
    
    return load_data_generic(models_to_examine, load_naive=False, metric='ccnorm_5', squared=squared,
                             percentages_to_load=(100,),
                            score_col_name=score_col_name, modelname_alternative=modelname_alternative)

# %%
df_all_cc2 = check_all(squared=True, score_col_name='cc2').xs(100, level='percentage').sort_index()
# Out:
# MkA_Shape all
# MkA_Shape OT
# MkE2_Shape all
# MkE2_Shape OT

# %%
HO_neuron_perf = df_all_cc2.apply(lambda x: x['cc2']['HO']['mean'], axis=1).unstack('subset')
HO_neuron_perf
# Out:
# subset                                 OT       all
# dataset    model
# MkA_Shape  vgg16$,00,conv1_1     0.121293  0.212053
#            vgg16$,01,conv1_2     0.131301  0.248452
#            vgg16$,02,pool1       0.144195  0.276834
#            vgg16$,03,conv2_1     0.158557  0.322921
#            vgg16$,04,conv2_2     0.175794  0.339092
#            vgg16$,05,pool2       0.204406  0.367980
#            vgg16$,06,conv3_1     0.209091  0.386387
#            vgg16$,07,conv3_2     0.176045  0.290204
#            vgg16$,08,conv3_3     0.171948  0.302682
#            vgg16$,09,pool3       0.175953  0.315842
#            vgg16$,10,conv4_1     0.201353  0.401131
#            vgg16$,11,conv4_2     0.189626  0.376893
#            vgg16$,12,conv4_3     0.170124  0.351755
#            vgg16$,13,pool4       0.174067  0.344126
#            vgg16$,14,conv5_1     0.172506  0.347393
#            vgg16$,15,conv5_2     0.153243  0.323108
#            vgg16$,16,conv5_3     0.134836  0.278167
#            vgg16$,17,pool5       0.141001  0.292808
#            vgg16$,18,fc6         0.148045  0.356523
#            vgg16$,19,fc7         0.139088  0.327826
#            vgg16_bn$,00,conv1_1  0.108762  0.189283
#            vgg16_bn$,01,conv1_2  0.128151  0.230377
#            vgg16_bn$,02,pool1    0.141297  0.257080
#            vgg16_bn$,03,conv2_1  0.153262  0.298505
#            vgg16_bn$,04,conv2_2  0.166420  0.321338
#            vgg16_bn$,05,pool2    0.196889  0.350335
#            vgg16_bn$,06,conv3_1  0.199606  0.370162
#            vgg16_bn$,07,conv3_2  0.170814  0.274198
#            vgg16_bn$,08,conv3_3  0.170261  0.297102
#            vgg16_bn$,09,pool3    0.176019  0.313145
# ...                                   ...       ...
# MkE2_Shape vgg19$,16,conv5_1     0.172285  0.290387
#            vgg19$,17,conv5_2     0.162365  0.265777
#            vgg19$,18,conv5_3     0.149591  0.252165
#            vgg19$,19,conv5_4     0.132917  0.222062
#            vgg19$,20,pool5       0.134259  0.229809
#            vgg19$,21,fc6         0.142046  0.272354
#            vgg19$,22,fc7         0.131677  0.245775
#            vgg19_bn$,00,conv1_1  0.131250  0.222794
#            vgg19_bn$,01,conv1_2  0.153084  0.260982
#            vgg19_bn$,02,pool1    0.177973  0.283616
#            vgg19_bn$,03,conv2_1  0.177302  0.309737
#            vgg19_bn$,04,conv2_2  0.202136  0.330745
#            vgg19_bn$,05,pool2    0.227109  0.348963
#            vgg19_bn$,06,conv3_1  0.234125  0.359385
#            vgg19_bn$,07,conv3_2  0.197958  0.273121
#            vgg19_bn$,08,conv3_3  0.186074  0.260014
#            vgg19_bn$,09,conv3_4  0.191487  0.283378
#            vgg19_bn$,10,pool3    0.196078  0.284881
#            vgg19_bn$,11,conv4_1  0.220577  0.360842
#            vgg19_bn$,12,conv4_2  0.211812  0.351860
#            vgg19_bn$,13,conv4_3  0.201681  0.344944
#            vgg19_bn$,14,conv4_4  0.197181  0.328227
#            vgg19_bn$,15,pool4    0.187920  0.315756
#            vgg19_bn$,16,conv5_1  0.176484  0.308823
#            vgg19_bn$,17,conv5_2  0.161754  0.284786
#            vgg19_bn$,18,conv5_3  0.154836  0.264508
#            vgg19_bn$,19,conv5_4  0.135027  0.229634
#            vgg19_bn$,20,pool5    0.138257  0.228401
#            vgg19_bn$,21,fc6      0.142236  0.267361
#            vgg19_bn$,22,fc7      0.130757  0.243795
#
# [172 rows x 2 columns]

# %%
OT_neuron_perf = df_all_cc2.apply(lambda x: x['cc2']['OT']['mean'], axis=1).unstack('subset')
OT_neuron_perf
# Out:
# subset                                 OT       all
# dataset    model
# MkA_Shape  vgg16$,00,conv1_1     0.229745  0.302892
#            vgg16$,01,conv1_2     0.251521  0.344093
#            vgg16$,02,pool1       0.295180  0.369149
#            vgg16$,03,conv2_1     0.332517  0.417191
#            vgg16$,04,conv2_2     0.355640  0.431578
#            vgg16$,05,pool2       0.414426  0.455260
#            vgg16$,06,conv3_1     0.419389  0.466032
#            vgg16$,07,conv3_2     0.354214  0.343635
#            vgg16$,08,conv3_3     0.343961  0.345655
#            vgg16$,09,pool3       0.362783  0.356149
#            vgg16$,10,conv4_1     0.425835  0.452737
#            vgg16$,11,conv4_2     0.401084  0.418476
#            vgg16$,12,conv4_3     0.366374  0.389470
#            vgg16$,13,pool4       0.372643  0.385806
#            vgg16$,14,conv5_1     0.368929  0.385620
#            vgg16$,15,conv5_2     0.339407  0.351296
#            vgg16$,16,conv5_3     0.312693  0.301276
#            vgg16$,17,pool5       0.316820  0.317883
#            vgg16$,18,fc6         0.336063  0.398494
#            vgg16$,19,fc7         0.314620  0.360910
#            vgg16_bn$,00,conv1_1  0.198363  0.272300
#            vgg16_bn$,01,conv1_2  0.243987  0.323009
#            vgg16_bn$,02,pool1    0.282663  0.345712
#            vgg16_bn$,03,conv2_1  0.315101  0.396305
#            vgg16_bn$,04,conv2_2  0.343268  0.420205
#            vgg16_bn$,05,pool2    0.395759  0.440923
#            vgg16_bn$,06,conv3_1  0.415096  0.453433
#            vgg16_bn$,07,conv3_2  0.331054  0.335270
#            vgg16_bn$,08,conv3_3  0.334221  0.352933
#            vgg16_bn$,09,pool3    0.356708  0.364882
# ...                                   ...       ...
# MkE2_Shape vgg19$,16,conv5_1     0.379454  0.382564
#            vgg19$,17,conv5_2     0.347182  0.344723
#            vgg19$,18,conv5_3     0.332074  0.322795
#            vgg19$,19,conv5_4     0.292859  0.283528
#            vgg19$,20,pool5       0.305084  0.293456
#            vgg19$,21,fc6         0.301379  0.359593
#            vgg19$,22,fc7         0.275005  0.319788
#            vgg19_bn$,00,conv1_1  0.316172  0.370138
#            vgg19_bn$,01,conv1_2  0.350158  0.422099
#            vgg19_bn$,02,pool1    0.396152  0.440497
#            vgg19_bn$,03,conv2_1  0.417589  0.470642
#            vgg19_bn$,04,conv2_2  0.454521  0.498894
#            vgg19_bn$,05,pool2    0.493417  0.513181
#            vgg19_bn$,06,conv3_1  0.499577  0.520456
#            vgg19_bn$,07,conv3_2  0.444218  0.415503
#            vgg19_bn$,08,conv3_3  0.422828  0.397653
#            vgg19_bn$,09,conv3_4  0.433781  0.420325
#            vgg19_bn$,10,pool3    0.437475  0.413558
#            vgg19_bn$,11,conv4_1  0.489770  0.492460
#            vgg19_bn$,12,conv4_2  0.466467  0.475307
#            vgg19_bn$,13,conv4_3  0.463978  0.460351
#            vgg19_bn$,14,conv4_4  0.435835  0.433273
#            vgg19_bn$,15,pool4    0.423535  0.420571
#            vgg19_bn$,16,conv5_1  0.400549  0.403413
#            vgg19_bn$,17,conv5_2  0.368456  0.368710
#            vgg19_bn$,18,conv5_3  0.352448  0.332482
#            vgg19_bn$,19,conv5_4  0.295568  0.288573
#            vgg19_bn$,20,pool5    0.295341  0.293000
#            vgg19_bn$,21,fc6      0.291989  0.352077
#            vgg19_bn$,22,fc7      0.274452  0.318188
#
# [172 rows x 2 columns]

# %%
from tang_jcompneuro.plotting import image_subset_and_neuron_subset_list, show_perf_vs_size
from tang_jcompneuro import dir_dictionary
import os.path

# %%
# from collections import OrderedDict

# %%
# time to plot.
# magic numbers here follow
# https://github.com/leelabcnbc/tang_jcompneuro/blob/master/thesis_plots/v1_fitting/results_performance_vgg.ipynb
def draw_one_stuff(dataset, net_name):
    # draw one by one.
    
    num_panel = len(image_subset_and_neuron_subset_list)
    
    plt.close('all')
    fig, ax = plt.subplots(1, 1, squeeze=True, figsize=(5.5,2.5))
    
    color_list = ('#1f77b4', '#ff7f0e', '#2ca02c')
    data_x_first = None
    xdatas = []
    ydatas = []
    labels = []
    style_list = []
    for idx, (img_subset, neuron_subset) in enumerate(image_subset_and_neuron_subset_list):
            
        if neuron_subset == 'OT':
            data_y = OT_neuron_perf[img_subset].loc[dataset].values
            data_x = OT_neuron_perf[img_subset].loc[dataset].index.values
        elif neuron_subset == 'HO':
            data_y = HO_neuron_perf[img_subset].loc[dataset].values
            data_x = HO_neuron_perf[img_subset].loc[dataset].index.values
        else:
            raise NotImplementedError
        data_y = np.asarray([v for idx_v, v in enumerate(data_y) if data_x[idx_v].startswith(f'{net_name}$')])
        data_x = [v[len(net_name)+5:] for idx_v, v in enumerate(data_x) if data_x[idx_v].startswith(f'{net_name}$')]
#         print(data_y.shape, data_x)
        
        if data_x_first is None:
            data_x_first = data_x
        assert data_x_first == data_x
        
        xdatas.append(np.arange(len(data_x)))
        ydatas.append(data_y)
        labels.append(f'{neuron_subset} neurons\n{img_subset} stimuli')
        style_list.append(('-', color_list[idx], 'x'))
        

    show_perf_vs_size(xdatas, ydatas, labels,
#                       title=f'{neuron_subset} neurons\n{img_subset} stimuli',
                      ax=ax,
                      ylabel='mean $CC_\mathrm{norm}^2$',
                      style_list=style_list, show_legend=True,
                      xticks=np.arange(len(data_x_first)),
                      xticklabels=data_x_first,
                      legend_param=dict(loc='best', ncol=3),
                      xlim=(-0.5, len(data_x_first)-0.5), xlabel=f'{net_name} layer',
                      xlabel_param={'rotation': 'vertical'}
                     )
#         )
#     mk = {'MkA_Shape': 'A', 'MkE2_Shape': 'B'}[dataset]
#     fig.suptitle(f'{net_name} on monkey {mk}')
#     # adjust figure 
    fig.text(0, 1, 'g',
                            horizontalalignment='left',
                            verticalalignment='top', fontweight='bold',
                            transform=fig.transFigure)
    fig.subplots_adjust(top=0.95, bottom=0.4, left=0.13, right=0.99, hspace=0.1, wspace=0.05)
#     fig.subplots_adjust(top=0.75, bottom=0.2, left=0.11, right=0.96, hspace=0.1, wspace=0.075)
    save_dir = os.path.join(dir_dictionary['plots'], 'main', 'vgg')
    os.makedirs(save_dir, exist_ok=True)
    fig.savefig(os.path.join(save_dir, f'{net_name}_{dataset}.pdf'), dpi=300)
    
    plt.show()

# %%
draw_one_stuff('MkA_Shape', 'vgg16')
draw_one_stuff('MkA_Shape', 'vgg19')
draw_one_stuff('MkA_Shape', 'vgg16_bn')
draw_one_stuff('MkA_Shape', 'vgg19_bn')

# %%
draw_one_stuff('MkE2_Shape', 'vgg16')
draw_one_stuff('MkE2_Shape', 'vgg19')
draw_one_stuff('MkE2_Shape', 'vgg16_bn')
draw_one_stuff('MkE2_Shape', 'vgg19_bn')
