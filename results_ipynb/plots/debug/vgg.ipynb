# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from tang_jcompneuro.model_fitting_postprocess import load_data_generic
from tang_jcompneuro.model_fitting_cnnpre import blob_corresponding_info, subtype_to_train

# %%
def modelname_alternative(_1, x, _2, _3):
    net_name, _, blob = x.split('+')
    assert _ == 'legacy'
    return net_name + ',{:02d},'.format(list(blob_corresponding_info[net_name]).index(blob)) + blob

# %%
def check_all(squared, score_col_name):
    models_to_examine = [
        ('cnnpre', x) for x in subtype_to_train if x.startswith('vgg16')  # both bn or nonbn
    ]
    
    
    return load_data_generic(models_to_examine, load_naive=False, metric='ccnorm_5', squared=squared,
                            score_col_name=score_col_name, modelname_alternative=modelname_alternative,
                            datasets_to_check=('MkA_Shape',
#                                                'MkE2_Shape'
                                              ),
                      subsets_to_check=('all',
#                                         'OT'
                                       ),)

# %%
df_all_cc2 = check_all(squared=True, score_col_name='cc2').xs(100, level='percentage').sort_index()
# Out:
# MkA_Shape all

# %%
HO_neuron_perf = df_all_cc2.apply(lambda x: x['cc2']['HO']['mean'], axis=1).unstack('subset')
HO_neuron_perf
# Out:
# subset                              all
# dataset   model
# MkA_Shape vgg16,00,conv1_1     0.212053
#           vgg16,01,conv1_2     0.248452
#           vgg16,02,pool1       0.276834
#           vgg16,03,conv2_1     0.322921
#           vgg16,04,conv2_2     0.339092
#           vgg16,05,pool2       0.367980
#           vgg16,06,conv3_1     0.386387
#           vgg16,07,conv3_2     0.290204
#           vgg16,08,conv3_3     0.302682
#           vgg16,09,pool3       0.315842
#           vgg16,10,conv4_1     0.401131
#           vgg16,11,conv4_2     0.376893
#           vgg16,12,conv4_3     0.351755
#           vgg16,13,pool4       0.344126
#           vgg16,14,conv5_1     0.347393
#           vgg16,15,conv5_2     0.323108
#           vgg16,16,conv5_3     0.278167
#           vgg16,17,pool5       0.292808
#           vgg16,18,fc6         0.356523
#           vgg16,19,fc7         0.327826
#           vgg16_bn,00,conv1_1  0.189283
#           vgg16_bn,01,conv1_2  0.230377
#           vgg16_bn,02,pool1    0.257080
#           vgg16_bn,03,conv2_1  0.298505
#           vgg16_bn,04,conv2_2  0.321338
#           vgg16_bn,05,pool2    0.350335
#           vgg16_bn,06,conv3_1  0.370162
#           vgg16_bn,07,conv3_2  0.274198
#           vgg16_bn,08,conv3_3  0.297102
#           vgg16_bn,09,pool3    0.313145
#           vgg16_bn,10,conv4_1  0.395748
#           vgg16_bn,11,conv4_2  0.382420
#           vgg16_bn,12,conv4_3  0.358069
#           vgg16_bn,13,pool4    0.352883
#           vgg16_bn,14,conv5_1  0.347730
#           vgg16_bn,15,conv5_2  0.324486
#           vgg16_bn,16,conv5_3  0.288244
#           vgg16_bn,17,pool5    0.296526
#           vgg16_bn,18,fc6      0.351612
#           vgg16_bn,19,fc7      0.321810

# %%
OT_neuron_perf = df_all_cc2.apply(lambda x: x['cc2']['OT']['mean'], axis=1).unstack('subset')
OT_neuron_perf
# Out:
# subset                              all
# dataset   model
# MkA_Shape vgg16,00,conv1_1     0.302892
#           vgg16,01,conv1_2     0.344093
#           vgg16,02,pool1       0.369149
#           vgg16,03,conv2_1     0.417191
#           vgg16,04,conv2_2     0.431578
#           vgg16,05,pool2       0.455260
#           vgg16,06,conv3_1     0.466032
#           vgg16,07,conv3_2     0.343635
#           vgg16,08,conv3_3     0.345655
#           vgg16,09,pool3       0.356149
#           vgg16,10,conv4_1     0.452737
#           vgg16,11,conv4_2     0.418476
#           vgg16,12,conv4_3     0.389470
#           vgg16,13,pool4       0.385806
#           vgg16,14,conv5_1     0.385620
#           vgg16,15,conv5_2     0.351296
#           vgg16,16,conv5_3     0.301276
#           vgg16,17,pool5       0.317883
#           vgg16,18,fc6         0.398494
#           vgg16,19,fc7         0.360910
#           vgg16_bn,00,conv1_1  0.272300
#           vgg16_bn,01,conv1_2  0.323009
#           vgg16_bn,02,pool1    0.345712
#           vgg16_bn,03,conv2_1  0.396305
#           vgg16_bn,04,conv2_2  0.420205
#           vgg16_bn,05,pool2    0.440923
#           vgg16_bn,06,conv3_1  0.453433
#           vgg16_bn,07,conv3_2  0.335270
#           vgg16_bn,08,conv3_3  0.352933
#           vgg16_bn,09,pool3    0.364882
#           vgg16_bn,10,conv4_1  0.451845
#           vgg16_bn,11,conv4_2  0.428934
#           vgg16_bn,12,conv4_3  0.396422
#           vgg16_bn,13,pool4    0.394786
#           vgg16_bn,14,conv5_1  0.393044
#           vgg16_bn,15,conv5_2  0.358259
#           vgg16_bn,16,conv5_3  0.314024
#           vgg16_bn,17,pool5    0.324644
#           vgg16_bn,18,fc6      0.395550
#           vgg16_bn,19,fc7      0.356475
